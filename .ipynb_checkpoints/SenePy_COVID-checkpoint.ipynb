# %%
# import senepy as sp
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sci
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# %%
# gtex_raw = sc.read("/mnt/data1/wangj/MyProject/Data/GTEx/Bulk_SnRNA/GTEx_8_tissues_snRNAseq_atlas_071421.public_obs.h5ad")
# gtex = gtex_raw.raw.to_adata()
# gtex

# %%
hca = sc.read("/home/wangjing/wangj/AgingScore/AgingScorePro/HCA/HCL_Fig1_adata.h5ad")
hca
# Out:
# AnnData object with n_obs × n_vars = 599926 × 27341
#     obs: 'batch', 'tissue', 'n_genes', 'n_counts'
#     var: 'n_cells'

# %%
hca_meta = pd.read_excel("/home/wangjing/wangj/AgingScore/AgingScorePro/HCA/HCL_Fig1_cell_Info.xlsx", index_col=0)
hca_meta
# Out:
#                                                           sample  cluster  \
# cellnames
# AdultAdipose_1.TATGTAACACCCGCAGGA                   AdultAdipose        2
# AdultAdipose_1.CTCGCAAATAAACATCCC                   AdultAdipose        2
# AdultAdipose_1.CGAGTATCGTAATACTTC                   AdultAdipose        2
# AdultAdipose_1.CTCGCAGCGAATCGGCAG                   AdultAdipose        2
# AdultAdipose_1.ACGTTGATCAACAGATGG                   AdultAdipose        2
# ...                                                          ...      ...
# NeonatalAdrenalGland_1.CCGCTAATTCCAGGACAT2  NeonatalAdrenalGland       12
# NeonatalAdrenalGland_1.TAGAGAGGGTTTTCGGGT2  NeonatalAdrenalGland       63
# NeonatalAdrenalGland_1.AAAACGTATGTACATGAT2  NeonatalAdrenalGland       63
# NeonatalAdrenalGland_1.ATGGCGTGCGGAATCAAC2  NeonatalAdrenalGland       63
# NeonatalAdrenalGland_1.CGCACCCTGTGTCCTTTC2  NeonatalAdrenalGland        2
#
# ...

# %%
hca_pheno = pd.read_excel("/home/wangjing/wangj/AgingScore/AgingScorePro/HCA/41586_2020_2157_MOESM2_ESM.xlsx", index_col=0,sheet_name='Sample Information')
hca_pheno
# Out:
#                                                                    Donor  \
# Tissues/Cell lines
# NaN                                                                  NaN
# Cord Blood1                                                       Donor1
# Cord Blood2                                                       Donor2
# Cord Blood1 (CD34+)                                               Donor1
# Cord Blood2 (CD34+)                                               Donor2
# ...                                                                  ...
# EB9 (Day9 Embryoid body derived from hiPSCs)      A Chinese Han iPS line
# EB18 (Day18 Embryoid body derived from hiPSCs)    A Chinese Han iPS line
# EB20 (Day20 Embryoid body derived from hiPSCs)    A Chinese Han iPS line
# Hematopoietic cell derived from H9/OP9 coculture                      H9
# Pancreatic beta cells derived from H9                                 H9
#
#                                                      Age  Gender  \
# ...

# %%
hca_pheno = hca_pheno.loc[[True if 'year-old' in str(age) else False for age in hca_pheno['Age']]]
hca_pheno
# Out:
#                                   Donor          Age  Gender Source of sample  \
# Tissues/Cell lines
# Adult Adipose1                  Donor20  36-year-old    Male              DCD
# Adult Adrenal Gland2            Donor21  52-year-old    Male              DCD
# Adult Adrenal Gland3            Donor22  23-year-old  Female              DCD
# Adult Artery1                   Donor23  46-year-old    Male              DCD
# Adult Ascending Colon1          Donor24  47-year-old  Female              DCD
# Adult Bladder1                  Donor25  52-year-old    Male              DCD
# Adult Bladder2                  Donor26  32-year-old  Female              DCD
# Adult Bone Marrow1              Donor27  60-year-old  Female        Operation
# Adult Bone Marrow2              Donor28  49-year-old  Female        Operation
# Adult Bone Marrow (mPB CD34-)1  Donor57  42-year-old    Male              NaN
# Adult Bone Marrow (mPB CD34-)2  Donor58  43-year-old    Male              NaN
# ...

# %%
cells = hca.obs_names.tolist()
cells = [i.split("-")[0] for i in cells]
cells[0:5]
# Out:
# ['AdultAdipose_1.TATGTAACACCCGCAGGA',
#  'AdultAdipose_1.CTCGCAAATAAACATCCC',
#  'AdultAdipose_1.CGAGTATCGTAATACTTC',
#  'AdultAdipose_1.CTCGCAGCGAATCGGCAG',
#  'AdultAdipose_1.ACGTTGATCAACAGATGG']

# %%
hca.obs['donor'] = hca_meta.loc[cells, 'donor'].tolist()
hca.obs['celltype'] = hca_meta.loc[cells, 'celltype'].tolist()
hca.obs['sample'] = hca_meta.loc[cells, 'sample'].tolist()

# %%
hca.obs['donor'].value_counts()
# Out:
# Donor23    39296
# Donor11    36761
# Donor5     32780
# Donor12    29616
# Donor9     25446
# Donor8     23499
# Donor34    23304
# Donor30    22346
# Donor49    21571
# Donor24    16989
# Donor31    16789
# Donor2     15741
# Donor22    15083
# Donor10    12673
# Donor13    11293
# Donor55    11229
# Donor32    10022
# Donor15     9932
# Donor41     9913
# Donor3      9898
# Donor44     9727
# Donor42     9603
# Donor4      9595
# Donor52     9544
# Donor36     9153
# Donor21     8114
# Donor51     8076
# Donor38     7833
# Donor43     7775
# Donor1      7757
# Donor29     7324
# Donor25     7256
# Donor48     7160
# Donor17     6616
# Donor28     6443
# Donor54     6328
# Donor53     6319
# Donor7      6053
# Donor19     5863
# Donor35     5549
# Donor46     5296
# Donor33     5031
# Donor50     4669
# Donor40     4384
# Donor39     4377
# Donor37     3849
# Donor16     3358
# Donor14     2770
# Donor26     2750
# Donor45     2719
# Donor6      2547
# Donor56     2390
# ...

# %%
Donors = np.unique(hca_pheno.Donor[hca_pheno.Donor.isin(hca.obs['donor'])])
Donors
# Out:
# array(['Donor20', 'Donor21', 'Donor22', 'Donor23', 'Donor24', 'Donor25',
#        'Donor26', 'Donor27', 'Donor28', 'Donor29', 'Donor30', 'Donor31',
#        'Donor32', 'Donor33', 'Donor34', 'Donor35', 'Donor36', 'Donor37',
#        'Donor38', 'Donor39', 'Donor40', 'Donor41', 'Donor42', 'Donor43',
#        'Donor44', 'Donor45', 'Donor46', 'Donor47', 'Donor48', 'Donor49',
#        'Donor50', 'Donor51', 'Donor52', 'Donor53', 'Donor54', 'Donor55',
#        'Donor56'], dtype=object)

# %%
hca_use = hca[hca.obs['donor'].isin(Donors),:]
hca_use
# Out:
# View of AnnData object with n_obs × n_vars = 344000 × 27341
#     obs: 'batch', 'tissue', 'n_genes', 'n_counts', 'donor', 'celltype', 'sample'
#     var: 'n_cells'

# %%
hca_Age = pd.DataFrame(hca_pheno[['Age','Donor']].drop_duplicates())
hca_Age.set_index('Donor', inplace=True)
hca_Age.head()
# Out:
#                  Age
# Donor
# Donor20  36-year-old
# Donor21  52-year-old
# Donor22  23-year-old
# Donor23  46-year-old
# Donor24  47-year-old

# %%
hca_use.obs['Age'] = hca_Age.loc[hca_use.obs['donor'], 'Age'].tolist()
hca_use.obs['Age'] = [int(s.replace('-year-old', '')) for s in hca_use.obs['Age'] ]
hca_use.obs['Age'].value_counts()
# Out:
# Trying to set attribute `.obs` of view, copying.
# 52    42093
# 46    39296
# 41    23304
# 51    21571
# 23    19467
# 49    18436
# 21    17746
# 47    16989
# 45    16789
# 61    15872
# 83    11229
# 57    10168
# 56    10022
# 43     9727
# 66     9153
# 62     8076
# 63     7775
# 55     7324
# 25     7160
# 64     5549
# 30     5296
# 58     5031
# 59     4669
# 32     2750
# 34     2719
# 60     2261
# 27     2156
# 36     1372
# Name: Age, dtype: int64

# %%
sc.pp.normalize_total(hca_use,target_sum=1e4)
sc.pp.log1p(hca_use)

# %%
hUSI = cal_hUSI(hca_use)
# Out:
# 100%|██████████| 344000/344000 [1:00:42<00:00, 94.45it/s]

# %%
hca_use.obs['hUSI'] = hUSI

# %%
hca_use.obs.celltype.value_counts()[1:20]
# Out:
# B cell (Plasmocyte)        27702
# Macrophage                 24143
# Smooth muscle cell         19925
# Enterocyte progenitor      15964
# Fasciculata cell           14234
# T cell                     13884
# Epithelial cell            13243
# Monocyte                   13091
# Stromal cell               12488
# Endothelial cell (APC)     12438
# Neutrophil                  8893
# Enterocyte                  8668
# Loop of Henle               8580
# Oligodendrocyte             7771
# Endothelial cell            7646
# Dendritic cell              7467
# AT2 cell                    7402
# Thyroid follicular cell     7302
# Basal cell                  6528
# Name: celltype, dtype: int64

# %%
df = hca_use.obs[['hUSI','Age','celltype']]
# df = df[df.tissue == 'AdultLung']
df
# Out:
#                                                   hUSI  Age  \
# index
# AdultAdipose_1.TATGTAACACCCGCAGGA-0           0.045239   36
# AdultAdipose_1.CTCGCAAATAAACATCCC-0           0.053311   36
# AdultAdipose_1.CGAGTATCGTAATACTTC-0           0.049357   36
# AdultAdipose_1.CTCGCAGCGAATCGGCAG-0           0.037303   36
# AdultAdipose_1.ACGTTGATCAACAGATGG-0           0.025337   36
# ...                                                ...  ...
# AdultTransverseColon_2.CCAGACTTAACTTCGGGT2-1  0.003819   83
# AdultTransverseColon_2.GGACATATGCTTGCCCTC2-1 -0.003192   83
# AdultTransverseColon_2.CTGTGTGGGCGAGCAGGA2-1  0.015641   83
# AdultTransverseColon_2.CCGACGATCTCTACACCC2-1  0.001640   83
# AdultTransverseColon_2.ATGCTTCACAAGGTTGCC2-1  0.008005   83
#
#                                                            celltype
# index
# AdultAdipose_1.TATGTAACACCCGCAGGA-0                      Macrophage
# AdultAdipose_1.CTCGCAAATAAACATCCC-0                      Macrophage
# ...

# %%
celltype_counts = df.groupby(['celltype', 'Age']).size().reset_index(name='count')
celltype_counts = celltype_counts[celltype_counts['count'] > 50]
celltype_occurrences = celltype_counts.groupby('celltype')['Age'].count().reset_index(name='num_age_groups')
selected_celltypes = celltype_occurrences[(celltype_occurrences['num_age_groups'] >= 10)]['celltype'].tolist()
df = df[df.celltype.isin(selected_celltypes)]
# print(df.celltype.value_counts())
df
# Out:
#                                                   hUSI  Age  \
# index
# AdultAdipose_1.TATGTAACACCCGCAGGA-0           0.045239   36
# AdultAdipose_1.CTCGCAAATAAACATCCC-0           0.053311   36
# AdultAdipose_1.CGAGTATCGTAATACTTC-0           0.049357   36
# AdultAdipose_1.CTCGCAGCGAATCGGCAG-0           0.037303   36
# AdultAdipose_1.ACGTTGATCAACAGATGG-0           0.025337   36
# ...                                                ...  ...
# AdultTransverseColon_2.CAACAATCTACCACGTTG2-1  0.017182   83
# AdultTransverseColon_2.TAGTCGCCAGACCGCTTG2-1  0.021722   83
# AdultTransverseColon_2.GGACATATGCTTGCCCTC2-1 -0.003192   83
# AdultTransverseColon_2.CCGACGATCTCTACACCC2-1  0.001640   83
# AdultTransverseColon_2.ATGCTTCACAAGGTTGCC2-1  0.008005   83
#
#                                                         celltype
# index
# AdultAdipose_1.TATGTAACACCCGCAGGA-0                   Macrophage
# AdultAdipose_1.CTCGCAAATAAACATCCC-0                   Macrophage
# ...

# %%
import joypy
import seaborn as sns
sns.set_theme(style="whitegrid",font_scale=1.2,font='arial')

for i in range(len(df['celltype'].unique())):
    data = df[df['celltype']==df['celltype'].unique()[i]]
    age_counts = data['Age'].value_counts()
    valid_age_groups = age_counts[age_counts > 50].index.tolist()
    data = data[data['Age'].isin(valid_age_groups)]
    fig,axes = joypy.joyplot(data,by='Age',column='hUSI',ylim='own',overlap=1,linewidth=1,
                       figsize=(6,6),alpha=0.5,legend=False,colormap=plt.cm.Reds)
#     me = data.groupby('Age').mean()['hUSI'].tolist()
#     for j in range(len(data.Age.value_counts())):
#         ymin = 0
#         ymax = axes[j].lines[1].get_ydata().max() 
#         axes[j].plot([me[j]] * 2, [ymin, ymax], color='black', linestyle='--', zorder=200)
    plt.axvline(x = data.hUSI.mean(),color='black', linestyle='--')
    font = {'family': 'arial','weight': 'normal','size': 25}
    plt.xlabel('hUSI',fontdict=font)
    plt.title(df['celltype'].unique()[i],fontdict=font)
    plt.savefig('/mnt/data1/wangj/codebase/HUSI/Figures/new/joyplot_'+df['celltype'].unique()[i]+'.png',dpi=400,bbox_inches = 'tight')
# Out:
# findfont: Font family ['arial'] not found. Falling back to DejaVu Sans.

# %%
df = df[df.celltype == 'Endothelial cell (APC)']
df
# Out:
#                                                   hUSI  Age  \
# index
# AdultAdipose_1.ACGTTGTCTACCTATTGT-0           0.031666   36
# AdultAdrenalGland_2.GCGAATTTGGACAGCGAG-0      0.029447   52
# AdultAdrenalGland_2.GCCCTCATCTCTTGTGCG-0      0.020948   52
# AdultAdrenalGland_2.GCGAATACACCCTTTAGG-0      0.029028   52
# AdultAdrenalGland_2.CGAGTAGCCCTCGTCGGT-0      0.038290   52
# ...                                                ...  ...
# AdultTransverseColon_2.TTCCGCTGGATGATGCTT2-1  0.030154   83
# AdultTransverseColon_2.ATGGCGTGCGGAGAGGAG2-1  0.020652   83
# AdultTransverseColon_2.ATGCTTGTGGTAACGAGC2-1  0.038200   83
# AdultTransverseColon_2.CTCCATGTTGCCTGCGGA2-1  0.019829   83
# AdultTransverseColon_2.CGTATTCGTGGCGTCGGT2-1  0.014751   83
#
#                                                             celltype
# index
# AdultAdipose_1.ACGTTGTCTACCTATTGT-0           Endothelial cell (APC)
# AdultAdrenalGland_2.GCGAATTTGGACAGCGAG-0      Endothelial cell (APC)
# ...

# %%
hca_end = hca_use[df.index]
hca_end
# Out:
# View of AnnData object with n_obs × n_vars = 12438 × 27341
#     obs: 'batch', 'tissue', 'n_genes', 'n_counts', 'donor', 'celltype', 'sample', 'Age', 'hUSI', 'age_class'
#     var: 'n_cells'
#     uns: 'log1p'

# %%
import random
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
from rpy2.robjects.vectors import FloatVector
import collections as clt

random.seed(123)
mclust = importr('mclust')
data = hca_end.obs['hUSI'].tolist()
data = [np.log2(1+i)/np.log2(1-i) for i in data]
r_data = FloatVector(data)
result = mclust.Mclust(r_data,G=2)  
clusters = result.rx2('classification')
clusters = list(clusters)
print(clt.Counter(clusters))
# Out:
# fitting ...
#   |======================================================================| 100%
# Counter({2.0: 6541, 1.0: 5897})

# %%
hca_end.obs['age_class'] = pd.Categorical(['C'+str(int(i)) for i in clusters])
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
sns.set(rc={'figure.figsize':(12,6)},font_scale=1.2,style='white')
sns.boxplot(hue='age_class',y='hUSI',x='celltype',data=hca_end.obs)
# Out:
# <AxesSubplot:xlabel='celltype', ylabel='hUSI'>

# %%
hca_end.write('/mnt/data1/wangj/codebase/HUSI/hca_end.h5ad')
# Out:
# ... storing 'donor' as categorical
# ... storing 'celltype' as categorical
# ... storing 'sample' as categorical

# %%
# sc.pp.highly_variable_genes(hca_end)
# hca_end.raw = hca_end
# hca_end = hca_end[:, hca_end.var.highly_variable]
# sc.pp.scale(hca_end)
# sc.tl.pca(hca_end)
sc.pp.neighbors(hca_end)
# sc.tl.umap(hca_end)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/numba/core/errors.py in new_error_context(fmt_, *args, **kwargs)
#     743
# --> 744     try:
#     745         yield
#
# ~/.local/lib/python3.6/site-packages/numba/core/lowering.py in lower_block(self, block)
#     229                                    loc=self.loc, errcls_=defaulterrcls):
# --> 230                 self.lower_inst(inst)
#     231         self.post_block(block)
#
# ~/.local/lib/python3.6/site-packages/numba/core/lowering.py in lower_inst(self, inst)
#     327             val = self.lower_assign(ty, inst)
# --> 328             self.storevar(val, inst.target.name)
#     329
#
# ~/.local/lib/python3.6/site-packages/numba/core/lowering.py in storevar(self, value, name)
#    1277             msg = ("Storing {value.type} to ptr of {ptr.type.pointee} "
# ...

# %%
sc.pl.umap(hca_end, color=['hUSI'])

# %% [markdown]
# ### snRNA-seq in GTEx

# %%
sc.pp.normalize_total(gtex,target_sum=1e4)
sc.pp.log1p(gtex)

# %%
import tqdm
def cal_hUSI(adata):
    mm_l2 = pd.read_csv('/home/wangjing/wangj/AgingScore/Data/Bulk_TrainModel/mm_l2.csv',index_col=0)
    genes = set(mm_l2.index) & set(adata.var_names)
    try:
        exp = adata[:,list(genes)].X.todense()
    except:
        exp = adata[:,list(genes)].X
    exp = pd.DataFrame(exp,index=adata.obs_names,columns=list(genes))
    score = []
    for row in tqdm.tqdm(range(len(exp))):
        score.append(mm_l2.w[genes].corr(exp.iloc[row],method='spearman'))
    return score

# %%
hUSI = cal_hUSI(gtex)

# %%
gtex.obs['hUSI'] = hUSI

# %%
gtex.obs.Age_bin.value_counts()

# %%
import random
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
from rpy2.robjects.vectors import FloatVector
import collections as clt

random.seed(123)
mclust = importr('mclust')
data = gtex.obs['hUSI'].tolist()
data = [np.log2(1+i)/np.log2(1-i) for i in data]
r_data = FloatVector(data)
result = mclust.Mclust(r_data)  
clusters = result.rx2('classification')
clusters = list(clusters)
print(clt.Counter(clusters))

# %%
gtex.obs['Senescence class'] = clusters

# %%
gtex.obs['tissue'].value_counts()

# %%
df = gtex.obs[['hUSI','Age_bin','tissue']]
df.head()

# %%
import joypy
sns.set_theme(style="whitegrid")
for i in range(len(df['tissue'].unique())):
    data = df[df['tissue']==df['tissue'].unique()[i]]
    joypy.joyplot(data,by='Age_bin',column='hUSI',ylim='own',overlap=1,linewidth=1,figsize=(8,4),alpha=0.5,legend=False,colormap=plt.cm.Reds)
    plt.xlabel('hUSI')
    plt.title(df['tissue'].unique()[i])
    # plt.savefig('/mnt/data1/wangj/MyProject/PhD_Project/aging/aging_score/aging_score/figure/joyplot/joyplot_'+df['tissue'].unique()[i]+'.png',dpi=300)

# %%
adata.obs['age_class'] = pd.Categorical(['C'+str(int(i)) for i in clusters])

# %%
adata.obs['age_class'].value_counts()

# %%
sns.set(rc={'figure.figsize':(12,6)},font_scale=1.2,style='white')
sns.boxplot(hue='age_class',y='hUSI',x='cell_type_main',data=adata.obs)

# %%
df = adata.obs

# %%
df_plot = df[['age_class','disease__ontology_label']].groupby(['age_class','disease__ontology_label']).size().reset_index().rename(columns={0:'count'})
df_plot['Fraction'] = df_plot['count'] / df_plot.groupby(['disease__ontology_label'])['count'].transform('sum')
df_plot['Sample'] = pd.Categorical(df_plot['disease__ontology_label'].apply(lambda x: 'COVID-19' if x == 'COVID-19' else 'Normal'),categories=['Normal','COVID-19'],ordered=True)
df_plot

# %%
df_plot2 = df[['age_class','hUSI']].groupby('age_class').mean().reset_index().rename(columns={0:'hUSI'})
df_plot2

# %% [markdown]
# ### Correlation with SenePy in GTEx

# %%
hubs = sp.load_hubs(species = 'Human')

# %%
### load the match Cell type
cell_map = pd.read_csv('/home/wangjing/wangj/codebase/HUSI/GTEx_SenePy.csv')
cell_map

# %%
### subset gext data
cell_use = {}
cell_uses = []
meta = gtex.obs
for index,row in cell_map.iterrows():
    types = row[0].split(';')
    cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
    cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]

# %%
gtex.obs.nUMIs.hist(bins=50)

# %%
gtex = gtex[cell_uses,:]
sc.pp.normalize_total(gtex,target_sum=1e4)
sc.pp.log1p(gtex)
gtex

# %%
ScoresList = {}
for key in cell_use.keys():
    cell = key.split('_')[0]
    tissue = key.split('_')[1]
    sub_gtex = gtex[cell_use[key]]
    print(key,sub_gtex.shape[0])
    
    genes = set(mm_l2.index) & set(sub_gtex.var_names)

    exp = sub_gtex[:,list(genes)].X.todense()
    exp = pd.DataFrame(exp,index=sub_gtex.obs_names,columns=list(genes))
    hUSI = []
    for row in range(len(exp)):  
        hUSI.append(mm_l2.w.corr(exp.iloc[row],method='spearman'))

    hub_names =  [i for i in hubs.hubs.keys() if cell in i and tissue in i]
    ScoresList[key] = {}
    ScoresList[key]['SenePy'] = {}
    for hub in hub_names:
        ScoresList[key]['SenePy']['_'.join(str(element) for element in hub)] = sp.score_hub(sub_gtex,hubs.hubs[hub])

    ScoresList[key]['hUSI'] =  hUSI

# %%
df_plot = pd.DataFrame()
for key in ScoresList.keys():
    cors = []
    for subkey in ScoresList[key]['SenePy'].keys():
        cors.append(sci.spearmanr(ScoresList[key]['SenePy'][subkey],ScoresList[key]['hUSI']).correlation)
    df_plot = pd.concat([df_plot,pd.DataFrame({'Cell type':key,'Cofficient':[np.max(cors)]})],ignore_index=True)

# %%
df_plot['tissue'] = df_plot['Cell type'].apply(lambda x: x.split('_')[1])
df_plot['type'] = df_plot['Cell type'].apply(lambda x: x.split('_')[0])
df_plot.tissue = pd.Categorical(df_plot.tissue,categories=['heart','skin','lung'],ordered=True)
df_plot = df_plot.sort_values(by='tissue',ascending=True,ignore_index=True)
df_plot

# %%
df_plot['counts'] = df_plot['Cell type'].apply(lambda x: len(cell_use[x]))
df_plot['type'] = [s.title() for s in df_plot['type']]
df_plot['type'] = df_plot['type'].replace('Type Ii Pneumocyte','Type II Pneumocyte')
df_plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=2,style='ticks')
plt.figure(figsize=(3.8,8))
ax = sns.scatterplot(x='tissue',y='type',hue='Cofficient',data=df_plot,s = 300)
plt.title('Spearman Correlation with SenePy',fontsize=25,loc='right')
plt.ylabel('Cell Type')
plt.xlim(-0.5, 3 - 0.5)
plt.rc('font',family='Arial', size=15)
plt.savefig("/home/wangjing/wangj/codebase/HUSI/Figures/model/GTEx_SenePy.pdf",dpi = 400,bbox_inches = 'tight')

# %%
### save tmp result
import pickle
with open('/mnt/data1/wangj/AgingScore/AgingScorePro/GTEx_SenePy.pkl', 'wb') as f:
    pickle.dump(ScoresList, f)

# %% [markdown]
# ### Appliction in COVID-19 dataset

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import os
import matplotlib.pyplot as plt

# %%
meta = pd.read_csv('/home/wangjing/wangj/AgingScore/GSE171524_NormalLung/lung_metaData.txt',index_col=0,sep='\t')
### remove 1 row
meta = meta.drop(['TYPE'],axis=0)
meta

# %%
meta.cell_type_fine.value_counts()

# %%
### read counts
files = os.listdir('/home/wangjing/wangj/AgingScore/GSE171524_NormalLung/Counts')
counts = pd.DataFrame()
cells = []
for file in files:
    tmp = pd.read_csv('/home/wangjing/wangj/AgingScore/GSE171524_NormalLung/Counts/'+file,index_col=0)
    tmp = tmp.T
    cells = cells + tmp.index.tolist()
    counts = pd.concat([counts,tmp],ignore_index=True)

# %%
import collections as clt
clt.Counter(meta.index.isin(cells))

# %%
counts.index = cells
counts = counts.loc[meta.index,:]

# %%
adata = sc.AnnData(counts)
adata.obs = meta
adata

# %%
plt.hist(adata.X.sum(axis=1))

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
adata.var['mt'] = adata.var_names.str.startswith('MT-')  
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(adata, keys=['total_counts'],groupby='disease__ontology_label',jitter=0.4, multi_panel=True)

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
adata[adata.obs.disease__ontology_label == 'COVID-19',:].obs.total_counts.hist(bins=50)
adata[adata.obs.disease__ontology_label == 'normal',:].obs.total_counts.hist(bins=50)
# plt.hist(list(adata[adata.obs.disease__ontology_label == 'COVID-19',:].X.sum(axis=1)))
# plt.hist(list(adata[adata.obs.disease__ontology_label == 'normal',:].X.sum(axis=1)))

# %%
adata.obs.disease__ontology_label.value_counts()

# %%
mm_l2 = pd.read_csv('/home/wangjing/wangj/AgingScore/Data/Bulk_TrainModel/mm_l2.csv',index_col=0)

# %%
adata.obs.cell_type_fine.value_counts()

# %%
genes = set(mm_l2.index) & set(adata.var_names)

exp = adata[:,list(genes)].X
exp = pd.DataFrame(exp,index=adata.obs_names,columns=list(genes))
hUSI = []
for row in range(len(exp)):  
    hUSI.append(mm_l2.w.corr(exp.iloc[row],method='spearman'))

# %%
adata.obs['hUSI'] = hUSI

# %%
df = adata.obs
df['Sample'] = pd.Categorical(df.disease__ontology_label,categories=['normal','COVID-19'],ordered=True)

# %%
adata.obs.cell_type_main.value_counts()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from statannot import add_stat_annotation
# sns.set(rc={'figure.figsize':(15,6)},font_scale=1.2)
# sns.set_style("white")
# sns.boxplot(hue='Sample',y='hUSI',x = 'cell_type_main',data=df,palette=['#023e8a','#e63946'])
# plt.xticks(rotation=30)
# plt.savefig("/home/wangjing/wangj/codebase/HUSI/Figures/model/Covid_hUSI.png",dpi = 400,bbox_inches = 'tight')

### boxplot significant: hUSI State Clsuter
sns.set(rc={'figure.figsize':(18,8)},font_scale=2)
sns.set_style("ticks")
ax = sns.boxplot(hue='Sample',y='hUSI',x = 'cell_type_main',data=df,palette=['#023e8a','#e63946'])
ax.set(xlabel='Cell Type')
pairs = []
for clu in adata.obs.cell_type_main.unique():
    pair = []
    for state in adata.obs.Sample.unique():
        pair.append((clu,state))
    pairs = pairs+list(itertools.combinations(pair, 2))
add_stat_annotation(ax, data=adata.obs, x="cell_type_main", y="hUSI",hue='Sample',
                    box_pairs=pairs,
                    test='Mann-Whitney', text_format='star', loc='inside', verbose=2,
                    comparisons_correction = "bonferroni",line_offset_to_box=0.02,line_offset=0.01)
plt.xticks(rotation=15, ha='right')
plt.rc('font',family='Arial', size=15)
plt.savefig("/home/wangjing/wangj/codebase/HUSI/Figures/model/Covid_hUSI.pdf",dpi = 400,bbox_inches = 'tight')

# %%
adata.obs.columns

# %%
import random
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
from rpy2.robjects.vectors import FloatVector
import collections as clt

random.seed(123)
mclust = importr('mclust')
data = adata.obs['hUSI'].tolist()
data = [np.log2(1+i)/np.log2(1-i) for i in data]
r_data = FloatVector(data)
result = mclust.Mclust(r_data)  
clusters = result.rx2('classification')
clusters = list(clusters)
print(clt.Counter(clusters))

# %%
adata.obs['age_class'] = pd.Categorical(['C'+str(int(i)) for i in clusters])

# %%
adata.obs['age_class'].value_counts()

# %%
sns.set(rc={'figure.figsize':(12,6)},font_scale=1.2,style='white')
sns.boxplot(hue='age_class',y='hUSI',x='cell_type_main',data=adata.obs)

# %%
df = adata.obs

# %%
df_plot = df[['age_class','disease__ontology_label']].groupby(['age_class','disease__ontology_label']).size().reset_index().rename(columns={0:'count'})
df_plot['Fraction'] = df_plot['count'] / df_plot.groupby(['disease__ontology_label'])['count'].transform('sum')
df_plot['Sample'] = pd.Categorical(df_plot['disease__ontology_label'].apply(lambda x: 'COVID-19' if x == 'COVID-19' else 'Normal'),categories=['Normal','COVID-19'],ordered=True)
df_plot

# %%
df_plot2 = df[['age_class','hUSI']].groupby('age_class').mean().reset_index().rename(columns={0:'hUSI'})
df_plot2

# %%
sns.set(rc={'figure.figsize':(5,8)},font_scale=1.5)
sns.set_style("white")
ax1 = sns.barplot(hue='Sample',y='Fraction',x='age_class',data=df_plot,palette=['#577590','#f94144'])
plt.xlabel('Senescence Class')
ax1.set_ylabel('Fraction', fontsize='20')
ax2 = ax1.twinx()  
ax2.set_ylim([-0.01, 0.06])      
ax2.plot(df_plot2.age_class, df_plot2.hUSI, '#adb5bd', ms=10, lw=3, marker='o') 
ax2.set_ylabel('hUSI', fontsize='20')
ax2.tick_params(labelsize=15)
plt.rc('font',family='Arial', size=15)
plt.savefig("/home/wangjing/wangj/codebase/HUSI/Figures/model/Covid_class.pdf",dpi = 500,bbox_inches = 'tight')

# %%
df = adata[adata.obs.disease__ontology_label == 'COVID-19'].obs[['cell_type_fine','age_class']].groupby(['cell_type_fine','age_class']).size().reset_index().rename(columns={0:'count'})
df['Fraction'] = df['count'] / df.groupby(['cell_type_fine'])['count'].transform('sum')
df1 = df
df = adata[adata.obs.disease__ontology_label == 'normal'].obs[['cell_type_fine','age_class']].groupby(['cell_type_fine','age_class']).size().reset_index().rename(columns={0:'count'})
df['Fraction'] = df['count'] / df.groupby(['cell_type_fine'])['count'].transform('sum')
df2= df

# %%
df['Fraction'] = df1['Fraction'] - df2['Fraction']
df['Count'] = df1['count'] + df2['count']
df[df.age_class == 'C4'].sort_values(by='Fraction',ascending=False)

# %%
df.cell_type_fine = pd.Categorical(df.cell_type_fine,categories=df[df.age_class.isin(['C4'])].sort_values(by='Fraction',ascending=False).cell_type_fine.to_list(),ordered=True)
df.head(10)

# %%
df['Class'] = df.age_class

# %%
sns.set(rc={'figure.figsize':(24,6)},font_scale=2)
sns.set_style("ticks")
ax = sns.scatterplot(x='cell_type_fine',
                        y='Fraction',
                        hue = 'Class',
                        size = 'Count',
                        data=df,
                        sizes=(500, 1200),
                        palette=['#577590','#43aa8b','#f3722c','#f94144'],
                        alpha=0.6)
### plot yline 
plt.axhline(y=0.15, color='#6c757d', linestyle='--')
plt.axhline(y=-0.15, color='#6c757d', linestyle='--')
### out legend
plt.legend(bbox_to_anchor=(1,0.5), loc='center left', ncol=1)
plt.xticks(rotation=90)
plt.setp(ax.get_xticklabels()[0:10], color='#f94144')
plt.ylabel('Fraction Difference')
plt.xlabel('Cell Subtype')
plt.rc('font',family='Arial', size=15)
plt.savefig("/home/wangjing/wangj/codebase/HUSI/Figures/model/Covid_Fra.pdf",dpi = 400,bbox_inches = 'tight')

# %%
### save tmp result
# with open('/mnt/data1/wangj/AgingScore/AgingScorePro/Covid_hUSI.pkl', 'wb') as f:
#     pickle.dump(adata.obs, f)

### load tmp result
import pickle
with open('/mnt/data1/wangj/AgingScore/AgingScorePro/Covid_hUSI.pkl', 'rb') as f:
    df = pickle.load(f)
