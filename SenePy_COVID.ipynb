# %% [markdown]
# ### Correlation with SenePy in GTEx

# %%
import senepy as sp
import scanpy as sc
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sci
import numpy as np

# %%
gtex_raw = sc.read("/mnt/data1/wangj/MyProject/Data/GTEx/Bulk_SnRNA/GTEx_8_tissues_snRNAseq_atlas_071421.public_obs.h5ad")
gtex = gtex_raw.raw.to_adata()
gtex
# Out:
# AnnData object with n_obs × n_vars = 209126 × 33694
#     obs: 'n_genes', 'fpr', 'tissue', 'prep', 'individual', 'nGenes', 'nUMIs', 'PercentMito', 'PercentRibo', 'Age_bin', 'Sex', 'Sample ID', 'Participant ID', 'Sample ID short', 'RIN score from PAXgene tissue Aliquot', 'RIN score from Frozen tissue Aliquot', 'Autolysis Score', 'Sample Ischemic Time (mins)', 'Tissue Site Detail', 'scrublet', 'scrublet_score', 'barcode', 'batch', 'n_counts', 'tissue-individual-prep', 'Broad cell type', 'Granular cell type', 'introns', 'junctions', 'exons', 'sense', 'antisense', 'intergenic', 'batch-barcode', 'exon_ratio', 'intron_ratio', 'junction_ratio', 'log10_nUMIs', 'leiden', 'leiden_tissue', 'Tissue composition', 'Cell types level 2', 'Cell types level 3', 'Broad cell type numbers', 'Broad cell type (numbers)', 'Tissue', 'channel'
#     var: 'gene_ids', 'Chromosome', 'Source', 'Start', 'End', 'Strand', 'gene_name', 'gene_source', 'gene_biotype', 'gene_length', 'gene_coding_length', 'Approved symbol', 'Approved name', 'Status', 'Previous symbols', 'Alias symbols'
#     uns: 'Broad cell type (numbers)_colors', 'Broad cell type numbers_colors', 'Broad cell type_colors', 'Broad cell type_logregcv_vae_colors', 'Broad cell type_sizes', 'Granular cell type_colors', 'Participant ID_colors', 'Sex_colors', 'Tissue composition_colors', 'Tissue_colors', "dendrogram_['Broad cell type']", 'leiden', 'leiden_colors', 'leiden_sub_colors', 'neighbors', 'paga', 'prep_colors', 'tissue_colors', 'umap'
#     obsm: 'X_pca', 'X_umap', 'X_umap_tissue', 'X_vae_mean', 'X_vae_mean_tissue', 'X_vae_samples', 'X_vae_var'
#     obsp: 'connectivities', 'distances'

# %%
mm_l2 = pd.read_csv('/home/wangjing/wangj/AgingScore/Data/Bulk_TrainModel/mm_l2.csv',index_col=0)

# %%
hubs = sp.load_hubs(species = 'Human')

# %%
### load the match Cell type
cell_map = pd.read_csv('/home/wangjing/wangj/codebase/HUSI/GTEx_SenePy.csv')
cell_map
# Out:
#                                                  GTEx Tissue_1  \
# 0   Endothelial cell (vascular);Endothelial cell (...     Lung
# 1                             Epithelial cell (basal)     Lung
# 2                          Epithelial cell (ciliated)     Lung
# 3                              Epithelial cell (club)     Lung
# 4                                          Fibroblast     Lung
# 5       Immune (DC/macrophage);Immune (DC/macrophage)     Lung
# 6                                     Immune (T cell)     Lung
# 7                  Epithelial cell (alveolar type II)     Lung
# 8                                   Myocyte (cardiac)    Heart
# 9                                           Adipocyte    Heart
# 10  Endothelial cell (vascular);Endothelial cell (...    Heart
# 11                                         Fibroblast    Heart
# 12  Immune (T cell);Immune (B cell) ;Immune (NK cell)    Heart
# 13                                         Fibroblast     Skin
# 14               Epithelial cell (basal keratinocyte)     Skin
# 15  Endothelial cell (vascular);Endothelial cell (...     Skin
# 16  Immune (DC/macrophage);Immune (T cell);Immune ...     Skin
#
#                       SenePy Tissue_2
# 0           endothelial cell     lung
# 1                 basal cell     lung
# 2   ciliated epithelial cell     lung
# 3                  club cell     lung
# 4                 fibroblast     lung
# 5                 macrophage     lung
# 6                     t cell     lung
# 7         type ii pneumocyte     lung
# 8              cardiomyocyte    heart
# 9                  adipocyte    heart
# 10          endothelial cell    heart
# 11                fibroblast    heart
# 12             lymphoid cell    heart
# 13                fibroblast     skin
# 14                basal cell     skin
# 15          endothelial cell     skin
# 16               immune cell     skin

# %%
### subset gext data
cell_use = {}
cell_uses = []
meta = gtex.obs
for index,row in cell_map.iterrows():
    types = row[0].split(';')
    cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
    cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# Out:
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]
# /tmp/ipykernel_54253/3530933997.py:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   types = row[0].split(';')
# /tmp/ipykernel_54253/3530933997.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_use[row[2]+"_"+row[3]] = meta.loc[(meta['Tissue']==row[1]) & (meta['Broad cell type'].isin(types))].index.tolist()
# /tmp/ipykernel_54253/3530933997.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   cell_uses = cell_uses + cell_use[row[2]+"_"+row[3]]

# %%
gtex.obs.nUMIs.hist(bins=50)
# Out:
# <Axes: >

# %%
gtex = gtex[cell_uses,:]
sc.pp.normalize_total(gtex,target_sum=1e4)
sc.pp.log1p(gtex)
gtex
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/scanpy/preprocessing/_normalization.py:169: UserWarning: Received a view of an AnnData. Making a copy.
#   view_to_actual(adata)
# AnnData object with n_obs × n_vars = 50515 × 33694
#     obs: 'n_genes', 'fpr', 'tissue', 'prep', 'individual', 'nGenes', 'nUMIs', 'PercentMito', 'PercentRibo', 'Age_bin', 'Sex', 'Sample ID', 'Participant ID', 'Sample ID short', 'RIN score from PAXgene tissue Aliquot', 'RIN score from Frozen tissue Aliquot', 'Autolysis Score', 'Sample Ischemic Time (mins)', 'Tissue Site Detail', 'scrublet', 'scrublet_score', 'barcode', 'batch', 'n_counts', 'tissue-individual-prep', 'Broad cell type', 'Granular cell type', 'introns', 'junctions', 'exons', 'sense', 'antisense', 'intergenic', 'batch-barcode', 'exon_ratio', 'intron_ratio', 'junction_ratio', 'log10_nUMIs', 'leiden', 'leiden_tissue', 'Tissue composition', 'Cell types level 2', 'Cell types level 3', 'Broad cell type numbers', 'Broad cell type (numbers)', 'Tissue', 'channel'
#     var: 'gene_ids', 'Chromosome', 'Source', 'Start', 'End', 'Strand', 'gene_name', 'gene_source', 'gene_biotype', 'gene_length', 'gene_coding_length', 'Approved symbol', 'Approved name', 'Status', 'Previous symbols', 'Alias symbols'
#     uns: 'Broad cell type (numbers)_colors', 'Broad cell type numbers_colors', 'Broad cell type_colors', 'Broad cell type_logregcv_vae_colors', 'Broad cell type_sizes', 'Participant ID_colors', 'Sex_colors', 'Tissue composition_colors', 'Tissue_colors', "dendrogram_['Broad cell type']", 'leiden', 'leiden_colors', 'leiden_sub_colors', 'neighbors', 'paga', 'prep_colors', 'tissue_colors', 'umap', 'log1p'
#     obsm: 'X_pca', 'X_umap', 'X_umap_tissue', 'X_vae_mean', 'X_vae_mean_tissue', 'X_vae_samples', 'X_vae_var'
#     obsp: 'connectivities', 'distances'

# %%
ScoresList = {}
for key in cell_use.keys():
    cell = key.split('_')[0]
    tissue = key.split('_')[1]
    sub_gtex = gtex[cell_use[key]]
    print(key,sub_gtex.shape[0])
    
    genes = set(mm_l2.index) & set(sub_gtex.var_names)

    exp = sub_gtex[:,list(genes)].X.todense()
    exp = pd.DataFrame(exp,index=sub_gtex.obs_names,columns=list(genes))
    hUSI = []
    for row in range(len(exp)):  
        hUSI.append(mm_l2.w.corr(exp.iloc[row],method='spearman'))

    hub_names =  [i for i in hubs.hubs.keys() if cell in i and tissue in i]
    ScoresList[key] = {}
    ScoresList[key]['SenePy'] = {}
    for hub in hub_names:
        ScoresList[key]['SenePy']['_'.join(str(element) for element in hub)] = sp.score_hub(sub_gtex,hubs.hubs[hub])

    ScoresList[key]['hUSI'] =  hUSI
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# endothelial cell_lung 2746
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# basal cell_lung 142
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# ciliated epithelial cell_lung 896
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# club cell_lung 660
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# fibroblast_lung 1476
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# macrophage_lung 921
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# t cell_lung 613
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# type ii pneumocyte_lung 15103
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# cardiomyocyte_heart 7041
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# adipocyte_heart 193
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# endothelial cell_heart 7635
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# fibroblast_heart 9287
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# lymphoid cell_heart 676
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# fibroblast_skin 529
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# basal cell_skin 1320
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# endothelial cell_skin 1023
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# immune cell_skin 254
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):

# %%
df_plot = pd.DataFrame()
for key in ScoresList.keys():
    cors = []
    for subkey in ScoresList[key]['SenePy'].keys():
        cors.append(sci.spearmanr(ScoresList[key]['SenePy'][subkey],ScoresList[key]['hUSI']).correlation)
    df_plot = pd.concat([df_plot,pd.DataFrame({'Cell type':key,'Cofficient':[np.max(cors)]})],ignore_index=True)

# %%
df_plot['tissue'] = df_plot['Cell type'].apply(lambda x: x.split('_')[1])
df_plot['type'] = df_plot['Cell type'].apply(lambda x: x.split('_')[0])
df_plot.tissue = pd.Categorical(df_plot.tissue,categories=['heart','skin','lung'],ordered=True)
df_plot = df_plot.sort_values(by='tissue',ascending=True,ignore_index=True)
df_plot
# Out:
#                         Cell type  Cofficient tissue                      type
# 0             cardiomyocyte_heart    0.395836  heart             cardiomyocyte
# 1             lymphoid cell_heart    0.039768  heart             lymphoid cell
# 2                fibroblast_heart    0.424980  heart                fibroblast
# 3          endothelial cell_heart    0.187802  heart          endothelial cell
# 4                 adipocyte_heart   -0.206017  heart                 adipocyte
# 5                 basal cell_skin   -0.174132   skin                basal cell
# 6                 fibroblast_skin    0.351062   skin                fibroblast
# 7           endothelial cell_skin    0.104133   skin          endothelial cell
# 8                immune cell_skin    0.339690   skin               immune cell
# 9                     t cell_lung   -0.114659   lung                    t cell
# 10                macrophage_lung    0.269360   lung                macrophage
# 11                fibroblast_lung    0.255246   lung                fibroblast
# 12                 club cell_lung    0.285555   lung                 club cell
# 13  ciliated epithelial cell_lung    0.293307   lung  ciliated epithelial cell
# 14                basal cell_lung    0.388232   lung                basal cell
# 15        type ii pneumocyte_lung    0.179491   lung        type ii pneumocyte
# 16          endothelial cell_lung    0.124060   lung          endothelial cell

# %%
df_plot['counts'] = df_plot['Cell type'].apply(lambda x: len(cell_use[x]))
df_plot['type'] = [s.title() for s in df_plot['type']]
df_plot['type'] = df_plot['type'].replace('Type Ii Pneumocyte','Type II Pneumocyte')
df_plot
# Out:
#                         Cell type  Cofficient tissue  \
# 0             cardiomyocyte_heart    0.395836  heart
# 1             lymphoid cell_heart    0.039768  heart
# 2                fibroblast_heart    0.424980  heart
# 3          endothelial cell_heart    0.187802  heart
# 4                 adipocyte_heart   -0.206017  heart
# 5                 basal cell_skin   -0.174132   skin
# 6                 fibroblast_skin    0.351062   skin
# 7           endothelial cell_skin    0.104133   skin
# 8                immune cell_skin    0.339690   skin
# 9                     t cell_lung   -0.114659   lung
# 10                macrophage_lung    0.269360   lung
# 11                fibroblast_lung    0.255246   lung
# 12                 club cell_lung    0.285555   lung
# 13  ciliated epithelial cell_lung    0.293307   lung
# 14                basal cell_lung    0.388232   lung
# 15        type ii pneumocyte_lung    0.179491   lung
# 16          endothelial cell_lung    0.124060   lung
#
#                         type  counts
# 0              Cardiomyocyte    7041
# 1              Lymphoid Cell     676
# 2                 Fibroblast    9287
# 3           Endothelial Cell    7635
# 4                  Adipocyte     193
# 5                 Basal Cell    1320
# 6                 Fibroblast     529
# 7           Endothelial Cell    1023
# 8                Immune Cell     254
# 9                     T Cell     613
# 10                Macrophage     921
# 11                Fibroblast    1476
# 12                 Club Cell     660
# 13  Ciliated Epithelial Cell     896
# 14                Basal Cell     142
# 15        Type II Pneumocyte   15103
# 16          Endothelial Cell    2746

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(font_scale=2,style='white')
plt.figure(figsize=(3.8,8))
ax = sns.scatterplot(x='tissue',y='type',hue='Cofficient',data=df_plot,s = 300)
plt.title('Spearman Correlation with SenePy',fontsize=25,loc='right')
plt.ylabel('Cell Type')
plt.xlim(-0.5, 3 - 0.5)
plt.savefig("/home/wangjing/wangj/codebase/HUSI/Figures/model/GTEx_SenePy.png",dpi = 400,bbox_inches = 'tight')
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# ### Appliction in COVID-19 dataset

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import os
import matplotlib.pyplot as plt

# %%
meta = pd.read_csv('/home/wangjing/wangj/AgingScore/GSE171524_NormalLung/lung_metaData.txt',index_col=0,sep='\t')
### remove 1 row
meta = meta.drop(['TYPE'],axis=0)
meta
# Out:
# /tmp/ipykernel_54253/820619250.py:1: DtypeWarning: Columns (15,16,18,20,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv('/home/wangjing/wangj/AgingScore/GSE171524_NormalLung/lung_metaData.txt',index_col=0,sep='\t')
#                       biosample_id donor_id         species  \
# NAME
# ATTCACTGTAACAGGC-1_1        C51ctr   C51ctr  NCBITaxon:9606
# TAACTTCCAACCACGC-1_1        C51ctr   C51ctr  NCBITaxon:9606
# TTGGGTACACGACAAG-1_1        C51ctr   C51ctr  NCBITaxon:9606
# AGGCCACAGAGTCACG-1_1        C51ctr   C51ctr  NCBITaxon:9606
# CACTGAAGTCGAAGCA-1_1        C51ctr   C51ctr  NCBITaxon:9606
# ...                            ...      ...             ...
# CCTAAGAAGTTGTCAC-1_27       L22cov   L22cov  NCBITaxon:9606
# CGTGAATCATGTCTAG-1_27       L22cov   L22cov  NCBITaxon:9606
# GCCGATGAGTAAACGT-1_27       L22cov   L22cov  NCBITaxon:9606
# AGGGTGAGTATCAGGG-1_27       L22cov   L22cov  NCBITaxon:9606
# ATGGATCAGAGAGCAA-1_27       L22cov   L22cov  NCBITaxon:9606
#
#                       species__ontology_label        disease  \
# NAME
# ATTCACTGTAACAGGC-1_1             Homo sapiens   PATO:0000461
# TAACTTCCAACCACGC-1_1             Homo sapiens   PATO:0000461
# TTGGGTACACGACAAG-1_1             Homo sapiens   PATO:0000461
# AGGCCACAGAGTCACG-1_1             Homo sapiens   PATO:0000461
# CACTGAAGTCGAAGCA-1_1             Homo sapiens   PATO:0000461
# ...                                       ...            ...
# CCTAAGAAGTTGTCAC-1_27            Homo sapiens  MONDO:0100096
# CGTGAATCATGTCTAG-1_27            Homo sapiens  MONDO:0100096
# GCCGATGAGTAAACGT-1_27            Homo sapiens  MONDO:0100096
# AGGGTGAGTATCAGGG-1_27            Homo sapiens  MONDO:0100096
# ATGGATCAGAGAGCAA-1_27            Homo sapiens  MONDO:0100096
#
#                       disease__ontology_label           organ  \
# NAME
# ATTCACTGTAACAGGC-1_1                   normal  UBERON:0002048
# TAACTTCCAACCACGC-1_1                   normal  UBERON:0002048
# TTGGGTACACGACAAG-1_1                   normal  UBERON:0002048
# AGGCCACAGAGTCACG-1_1                   normal  UBERON:0002048
# CACTGAAGTCGAAGCA-1_1                   normal  UBERON:0002048
# ...                                       ...             ...
# CCTAAGAAGTTGTCAC-1_27                COVID-19  UBERON:0002048
# CGTGAATCATGTCTAG-1_27                COVID-19  UBERON:0002048
# GCCGATGAGTAAACGT-1_27                COVID-19  UBERON:0002048
# AGGGTGAGTATCAGGG-1_27                COVID-19  UBERON:0002048
# ATGGATCAGAGAGCAA-1_27                COVID-19  UBERON:0002048
#
#                       organ__ontology_label library_preparation_protocol  \
# NAME
# ATTCACTGTAACAGGC-1_1                   lung                  EFO:0009922
# TAACTTCCAACCACGC-1_1                   lung                  EFO:0009922
# TTGGGTACACGACAAG-1_1                   lung                  EFO:0009922
# AGGCCACAGAGTCACG-1_1                   lung                  EFO:0009922
# CACTGAAGTCGAAGCA-1_1                   lung                  EFO:0009922
# ...                                     ...                          ...
# CCTAAGAAGTTGTCAC-1_27                  lung                  EFO:0009922
# CGTGAATCATGTCTAG-1_27                  lung                  EFO:0009922
# GCCGATGAGTAAACGT-1_27                  lung                  EFO:0009922
# AGGGTGAGTATCAGGG-1_27                  lung                  EFO:0009922
# ATGGATCAGAGAGCAA-1_27                  lung                  EFO:0009922
#
#                       library_preparation_protocol__ontology_label  ...  \
# NAME                                                                ...
# ATTCACTGTAACAGGC-1_1                          10x 3' v3 sequencing  ...
# TAACTTCCAACCACGC-1_1                          10x 3' v3 sequencing  ...
# TTGGGTACACGACAAG-1_1                          10x 3' v3 sequencing  ...
# AGGCCACAGAGTCACG-1_1                          10x 3' v3 sequencing  ...
# CACTGAAGTCGAAGCA-1_1                          10x 3' v3 sequencing  ...
# ...                                                            ...  ...
# CCTAAGAAGTTGTCAC-1_27                         10x 3' v3 sequencing  ...
# CGTGAATCATGTCTAG-1_27                         10x 3' v3 sequencing  ...
# GCCGATGAGTAAACGT-1_27                         10x 3' v3 sequencing  ...
# AGGGTGAGTATCAGGG-1_27                         10x 3' v3 sequencing  ...
# ATGGATCAGAGAGCAA-1_27                         10x 3' v3 sequencing  ...
#
#                         cell_type_intermediate                cell_type_fine  \
# NAME
# ATTCACTGTAACAGGC-1_1   Airway epithelial cells               Airway ciliated
# TAACTTCCAACCACGC-1_1               Macrophages          Alveolar macrophages
# TTGGGTACACGACAAG-1_1   Airway epithelial cells               Airway ciliated
# AGGCCACAGAGTCACG-1_1   Airway epithelial cells               Airway ciliated
# CACTGAAGTCGAAGCA-1_1   Airway epithelial cells               Airway ciliated
# ...                                        ...                           ...
# CCTAAGAAGTTGTCAC-1_27              Fibroblasts  Intermediate pathological FB
# CGTGAATCATGTCTAG-1_27              Macrophages             Transitioning MDM
# GCCGATGAGTAAACGT-1_27                      AT2                           AT2
# AGGGTGAGTATCAGGG-1_27                      AT1                           AT1
# ATGGATCAGAGAGCAA-1_27              Macrophages  Monocyte-derived macrophages
#
#                       initial_clustering age     sex recorded_race  \
# NAME
# ATTCACTGTAACAGGC-1_1                  18  70  female         White
# TAACTTCCAACCACGC-1_1                   3  70  female         White
# TTGGGTACACGACAAG-1_1                  18  70  female         White
# AGGCCACAGAGTCACG-1_1                  18  70  female         White
# CACTGAAGTCGAAGCA-1_1                  18  70  female         White
# ...                                  ...  ..     ...           ...
# CCTAAGAAGTTGTCAC-1_27                  0  58    male           NaN
# CGTGAATCATGTCTAG-1_27                  9  58    male           NaN
# GCCGATGAGTAAACGT-1_27                 11  58    male           NaN
# AGGGTGAGTATCAGGG-1_27                  5  58    male           NaN
# ATGGATCAGAGAGCAA-1_27                  7  58    male           NaN
#
#                       recorded_ethnicity intubation_days  \
# NAME
# ATTCACTGTAACAGGC-1_1        not_hispanic             NaN
# TAACTTCCAACCACGC-1_1        not_hispanic             NaN
# TTGGGTACACGACAAG-1_1        not_hispanic             NaN
# AGGCCACAGAGTCACG-1_1        not_hispanic             NaN
# CACTGAAGTCGAAGCA-1_1        not_hispanic             NaN
# ...                                  ...             ...
# CCTAAGAAGTTGTCAC-1_27                NaN              56
# CGTGAATCATGTCTAG-1_27                NaN              56
# GCCGATGAGTAAACGT-1_27                NaN              56
# AGGGTGAGTATCAGGG-1_27                NaN              56
# ATGGATCAGAGAGCAA-1_27                NaN              56
#
#                       interval_death_symptoms_onset_days pmi_h
# NAME
# ATTCACTGTAACAGGC-1_1                                 NaN   NaN
# TAACTTCCAACCACGC-1_1                                 NaN   NaN
# TTGGGTACACGACAAG-1_1                                 NaN   NaN
# AGGCCACAGAGTCACG-1_1                                 NaN   NaN
# CACTGAAGTCGAAGCA-1_1                                 NaN   NaN
# ...                                                  ...   ...
# CCTAAGAAGTTGTCAC-1_27                                 63  6.75
# CGTGAATCATGTCTAG-1_27                                 63  6.75
# GCCGATGAGTAAACGT-1_27                                 63  6.75
# AGGGTGAGTATCAGGG-1_27                                 63  6.75
# ATGGATCAGAGAGCAA-1_27                                 63  6.75
#
# [116313 rows x 22 columns]

# %%
meta.cell_type_fine.value_counts()
# Out:
# cell_type_fine
# Alveolar macrophages                  12511
# AT2                                   11341
# AT1                                    9608
# Monocyte-derived macrophages           9534
# Intermediate pathological FB           8779
# CD4+ T cells                           7586
# Plasma cells                           5391
# Alveolar FB                            4670
# Transitioning MDM                      4203
# Adventitial FB                         3773
# CD8+ T cells                           3561
# Monocytes                              3176
# Cycling NK/T cells                     2814
# Airway ciliated                        2392
# Pathological FB                        2322
# NK cells                               2141
# Neuronal cells                         2017
# Airway goblet                          1757
# Mast cells                             1438
# Endothelial cells (general)            1360
# Airway mucous                          1307
# Activated B cells                      1299
# Airway club                            1232
# ECM-high epithelial                    1179
# Other FB                               1099
# Dendritic cells                        1083
# Airway smooth muscle                   1020
# Capillary endothelial cells            1010
# Arterial endothelial cells              937
# Tregs                                   649
# Cycling epithelial                      609
# Pericytes                               597
# Systemic venous endothelial cells       587
# Inflamed endothelial cells              566
# Pulmonary venous endothelial cells      553
# B cells                                 546
# Airway basal                            534
# Vascular smooth muscle                  417
# Endothelial cells (other)               373
# Mesothelial FB                          232
# Tuft-like                               110
# Name: count, dtype: int64

# %%
### read counts
files = os.listdir('/home/wangjing/wangj/AgingScore/GSE171524_NormalLung/Counts')
counts = pd.DataFrame()
cells = []
for file in files:
    tmp = pd.read_csv('/home/wangjing/wangj/AgingScore/GSE171524_NormalLung/Counts/'+file,index_col=0)
    tmp = tmp.T
    cells = cells + tmp.index.tolist()
    counts = pd.concat([counts,tmp],ignore_index=True)

# %%
import collections as clt
clt.Counter(meta.index.isin(cells))
# Out:
# Counter({True: 116313})

# %%
counts.index = cells
counts = counts.loc[meta.index,:]

# %%
adata = sc.AnnData(counts)
adata.obs = meta
adata
# Out:
# /tmp/ipykernel_54253/3872494685.py:1: FutureWarning: X.dtype being converted to np.float32 from int64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata = sc.AnnData(counts)
# AnnData object with n_obs × n_vars = 116313 × 34546
#     obs: 'biosample_id', 'donor_id', 'species', 'species__ontology_label', 'disease', 'disease__ontology_label', 'organ', 'organ__ontology_label', 'library_preparation_protocol', 'library_preparation_protocol__ontology_label', 'group', 'cell_type_main', 'cell_type_intermediate', 'cell_type_fine', 'initial_clustering', 'age', 'sex', 'recorded_race', 'recorded_ethnicity', 'intubation_days', 'interval_death_symptoms_onset_days', 'pmi_h'

# %%
plt.hist(adata.X.sum(axis=1))
# Out:
# (array([1.0962e+05, 5.3780e+03, 9.1500e+02, 2.4100e+02, 8.7000e+01,
#         4.2000e+01, 1.5000e+01, 1.0000e+01, 3.0000e+00, 2.0000e+00]),
#  array([  401.,  3842.,  7283., 10724., 14165., 17606., 21047., 24488.,
#         27929., 31370., 34811.]),
#  <BarContainer object of 10 artists>)

# %%
sc.pp.filter_cells(adata, min_genes=200)
sc.pp.filter_genes(adata, min_cells=3)
adata.var['mt'] = adata.var_names.str.startswith('MT-')  
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):

# %%
sc.pl.violin(adata, keys=['total_counts'],groupby='disease__ontology_label',jitter=0.4, multi_panel=True)
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/scanpy/plotting/_anndata.py:770: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(adata.obs[groupby]):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
adata[adata.obs.disease__ontology_label == 'COVID-19',:].obs.total_counts.hist(bins=50)
adata[adata.obs.disease__ontology_label == 'normal',:].obs.total_counts.hist(bins=50)
# plt.hist(list(adata[adata.obs.disease__ontology_label == 'COVID-19',:].X.sum(axis=1)))
# plt.hist(list(adata[adata.obs.disease__ontology_label == 'normal',:].X.sum(axis=1)))
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# <Axes: >

# %%
adata.obs.disease__ontology_label.value_counts()
# Out:
# disease__ontology_label
# COVID-19    79636
# normal      36677
# Name: count, dtype: int64

# %%
mm_l2 = pd.read_csv('/home/wangjing/wangj/AgingScore/Data/Bulk_TrainModel/mm_l2.csv',index_col=0)

# %%
adata.obs.cell_type_fine.value_counts()
# Out:
# cell_type_fine
# Alveolar macrophages                  12511
# AT2                                   11341
# AT1                                    9608
# Monocyte-derived macrophages           9534
# Intermediate pathological FB           8779
# CD4+ T cells                           7586
# Plasma cells                           5391
# Alveolar FB                            4670
# Transitioning MDM                      4203
# Adventitial FB                         3773
# CD8+ T cells                           3561
# Monocytes                              3176
# Cycling NK/T cells                     2814
# Airway ciliated                        2392
# Pathological FB                        2322
# NK cells                               2141
# Neuronal cells                         2017
# Airway goblet                          1757
# Mast cells                             1438
# Endothelial cells (general)            1360
# Airway mucous                          1307
# Activated B cells                      1299
# Airway club                            1232
# ECM-high epithelial                    1179
# Other FB                               1099
# Dendritic cells                        1083
# Airway smooth muscle                   1020
# Capillary endothelial cells            1010
# Arterial endothelial cells              937
# Tregs                                   649
# Cycling epithelial                      609
# Pericytes                               597
# Systemic venous endothelial cells       587
# Inflamed endothelial cells              566
# Pulmonary venous endothelial cells      553
# B cells                                 546
# Airway basal                            534
# Vascular smooth muscle                  417
# Endothelial cells (other)               373
# Mesothelial FB                          232
# Tuft-like                               110
# Name: count, dtype: int64

# %%
genes = set(mm_l2.index) & set(adata.var_names)

exp = adata[:,list(genes)].X
exp = pd.DataFrame(exp,index=adata.obs_names,columns=list(genes))
hUSI = []
for row in range(len(exp)):  
    hUSI.append(mm_l2.w.corr(exp.iloc[row],method='spearman'))
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):

# %%
adata.obs['hUSI'] = hUSI

# %%
df = adata.obs
df['Sample'] = pd.Categorical(df.disease__ontology_label,categories=['normal','COVID-19'],ordered=True)

# %%
adata.obs.cell_type_main.value_counts()
# Out:
# cell_type_main
# Epithelial cells     30069
# Myeloid              29632
# Fibroblasts          22909
# T cells              16751
# B cells               7236
# Endothelial cells     5386
# Neuronal cells        2017
# Mast cells            1464
# APC-like               849
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import itertools
from statannot import add_stat_annotation
# sns.set(rc={'figure.figsize':(15,6)},font_scale=1.2)
# sns.set_style("white")
# sns.boxplot(hue='Sample',y='hUSI',x = 'cell_type_main',data=df,palette=['#023e8a','#e63946'])
# plt.xticks(rotation=30)
# plt.savefig("/home/wangjing/wangj/codebase/HUSI/Figures/model/Covid_hUSI.png",dpi = 400,bbox_inches = 'tight')

### boxplot significant: hUSI State Clsuter
sns.set(rc={'figure.figsize':(18,8)},font_scale=2)
sns.set_style("white")
ax = sns.boxplot(hue='Sample',y='hUSI',x = 'cell_type_main',data=df,palette=['#023e8a','#e63946'])
ax.set(xlabel=None)
pairs = []
for clu in adata.obs.cell_type_main.unique():
    pair = []
    for state in adata.obs.Sample.unique():
        pair.append((clu,state))
    pairs = pairs+list(itertools.combinations(pair, 2))
add_stat_annotation(ax, data=adata.obs, x="cell_type_main", y="hUSI",hue='Sample',
                    box_pairs=pairs,
                    test='Mann-Whitney', text_format='star', loc='inside', verbose=2,
                    comparisons_correction = "bonferroni",line_offset_to_box=0.02,line_offset=0.01)
plt.xticks(rotation=15, ha='right')
plt.savefig("/home/wangjing/wangj/codebase/HUSI/Figures/model/Covid_hUSI.png",dpi = 400,bbox_inches = 'tight')
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# T cells_normal v.s. T cells_COVID-19: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=3.468e-23 U_stat=3.260e+07
# B cells_normal v.s. B cells_COVID-19: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.065e-26 U_stat=6.074e+06
# APC-like_normal v.s. APC-like_COVID-19: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.533e-01 U_stat=8.157e+04
# Endothelial cells_normal v.s. Endothelial cells_COVID-19: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.663e-35 U_stat=2.736e+06
# Epithelial cells_normal v.s. Epithelial cells_COVID-19: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=0.000e+00 U_stat=7.540e+07
# Myeloid_normal v.s. Myeloid_COVID-19: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.908e-164 U_stat=4.419e+07
# Fibroblasts_normal v.s. Fibroblasts_COVID-19: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.428e-277 U_stat=3.155e+07
# Mast cells_normal v.s. Mast cells_COVID-19: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=6.500e-02 U_stat=2.334e+05
# Neuronal cells_normal v.s. Neuronal cells_COVID-19: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.630e-17 U_stat=1.941e+05

# %%
adata.obs.columns
# Out:
# Index(['biosample_id', 'donor_id', 'species', 'species__ontology_label',
#        'disease', 'disease__ontology_label', 'organ', 'organ__ontology_label',
#        'library_preparation_protocol',
#        'library_preparation_protocol__ontology_label', 'group',
#        'cell_type_main', 'cell_type_intermediate', 'cell_type_fine',
#        'initial_clustering', 'age', 'sex', 'recorded_race',
#        'recorded_ethnicity', 'intubation_days',
#        'interval_death_symptoms_onset_days', 'pmi_h', 'n_genes',
#        'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt',
#        'hUSI', 'Sample'],
#       dtype='object')

# %%
import random
import rpy2.robjects as robjects
from rpy2.robjects.packages import importr
from rpy2.robjects.vectors import FloatVector
import collections as clt

random.seed(123)
mclust = importr('mclust')
data = adata.obs['hUSI'].tolist()
data = [np.log2(1+i)/np.log2(1-i) for i in data]
r_data = FloatVector(data)
result = mclust.Mclust(r_data)  
clusters = result.rx2('classification')
clusters = list(clusters)
print(clt.Counter(clusters))
# Out:
# fitting ...
#   |======================================================================| 100%
# Counter({2.0: 45742, 4.0: 30609, 3.0: 29048, 1.0: 10914})

# %%
adata.obs['age_class'] = pd.Categorical(['C'+str(int(i)) for i in clusters])

# %%
adata.obs['age_class'].value_counts()
# Out:
# age_class
# C2    45742
# C4    30609
# C3    29048
# C1    10914
# Name: count, dtype: int64

# %%
sns.set(rc={'figure.figsize':(12,6)},font_scale=1.2,style='white')
sns.boxplot(hue='age_class',y='hUSI',x='cell_type_main',data=adata.obs)
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='cell_type_main', ylabel='hUSI'>

# %%
df_plot = adata.obs[['age_class','disease__ontology_label']].groupby(['age_class','disease__ontology_label']).size().reset_index().rename(columns={0:'count'})
df_plot['Fraction'] = df_plot['count'] / df_plot.groupby(['disease__ontology_label'])['count'].transform('sum')
df_plot['Sample'] = pd.Categorical(df_plot['disease__ontology_label'].apply(lambda x: 'COVID-19' if x == 'COVID-19' else 'Normal'),categories=['Normal','COVID-19'],ordered=True)
df_plot
# Out:
# /tmp/ipykernel_54253/135249879.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_plot = adata.obs[['age_class','disease__ontology_label']].groupby(['age_class','disease__ontology_label']).size().reset_index().rename(columns={0:'count'})
# /tmp/ipykernel_54253/135249879.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_plot['Fraction'] = df_plot['count'] / df_plot.groupby(['disease__ontology_label'])['count'].transform('sum')
#   age_class disease__ontology_label  count  Fraction    Sample
# 0        C1                COVID-19   6794  0.085313  COVID-19
# 1        C1                  normal   4120  0.112332    Normal
# 2        C2                COVID-19  26670  0.334899  COVID-19
# 3        C2                  normal  19072  0.519999    Normal
# 4        C3                COVID-19  20168  0.253252  COVID-19
# 5        C3                  normal   8880  0.242114    Normal
# 6        C4                COVID-19  26004  0.326536  COVID-19
# 7        C4                  normal   4605  0.125556    Normal

# %%
df_plot2 = adata.obs[['age_class','hUSI']].groupby('age_class').mean().reset_index().rename(columns={0:'hUSI'})
df_plot2
# Out:
# /tmp/ipykernel_54253/976433332.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_plot2 = adata.obs[['age_class','hUSI']].groupby('age_class').mean().reset_index().rename(columns={0:'hUSI'})
#   age_class      hUSI
# 0        C1 -0.005834
# 1        C2  0.010252
# 2        C3  0.021569
# 3        C4  0.037363

# %%
sns.set(rc={'figure.figsize':(5,8)},font_scale=1.5)
sns.set_style("white")
ax1 = sns.barplot(hue='Sample',y='Fraction',x='age_class',data=df_plot,palette=['#577590','#f94144'])
ax1.set_ylabel('Fraction', fontsize='20')
ax2 = ax1.twinx()  
ax2.set_ylim([-0.01, 0.06])      
ax2.plot(df_plot2.age_class, df_plot2.hUSI, '#adb5bd', ms=10, lw=3, marker='o') 
ax2.set_ylabel('hUSI', fontsize='20')
ax2.tick_params(labelsize=15)
plt.savefig("/home/wangjing/wangj/codebase/HUSI/Figures/model/Covid_class.png",dpi = 500,bbox_inches = 'tight')
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
df = adata[adata.obs.disease__ontology_label == 'COVID-19'].obs[['cell_type_fine','age_class']].groupby(['cell_type_fine','age_class']).size().reset_index().rename(columns={0:'count'})
df['Fraction'] = df['count'] / df.groupby(['cell_type_fine'])['count'].transform('sum')
df1 = df
df = adata[adata.obs.disease__ontology_label == 'normal'].obs[['cell_type_fine','age_class']].groupby(['cell_type_fine','age_class']).size().reset_index().rename(columns={0:'count'})
df['Fraction'] = df['count'] / df.groupby(['cell_type_fine'])['count'].transform('sum')
df2= df
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /tmp/ipykernel_54253/1067260895.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = adata[adata.obs.disease__ontology_label == 'COVID-19'].obs[['cell_type_fine','age_class']].groupby(['cell_type_fine','age_class']).size().reset_index().rename(columns={0:'count'})
# /tmp/ipykernel_54253/1067260895.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['Fraction'] = df['count'] / df.groupby(['cell_type_fine'])['count'].transform('sum')
# /home/wangjing/miniconda3/lib/python3.9/site-packages/anndata/_core/anndata.py:1118: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if not is_categorical_dtype(df_full[k]):
# /tmp/ipykernel_54253/1067260895.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df = adata[adata.obs.disease__ontology_label == 'normal'].obs[['cell_type_fine','age_class']].groupby(['cell_type_fine','age_class']).size().reset_index().rename(columns={0:'count'})
# /tmp/ipykernel_54253/1067260895.py:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df['Fraction'] = df['count'] / df.groupby(['cell_type_fine'])['count'].transform('sum')

# %%
df['Fraction'] = df1['Fraction'] - df2['Fraction']
df['count'] = df1['count'] + df2['count']
df[df.age_class == 'C4'].sort_values(by='Fraction',ascending=False)
# Out:
#                          cell_type_fine age_class  count  Fraction
# 111        Monocyte-derived macrophages        C4   4954  0.319080
# 3                                   AT1        C4   2306  0.238490
# 123                      Neuronal cells        C4    593  0.199921
# 107                      Mesothelial FB        C4     97  0.198980
# 51           Arterial endothelial cells        C4    281  0.181224
# 131                     Pathological FB        C4   1103  0.175772
# 67          Capillary endothelial cells        C4    235  0.174986
# 95           Inflamed endothelial cells        C4    247  0.171550
# 99         Intermediate pathological FB        C4   1588  0.164040
# 7                                   AT2        C4    982  0.159438
# 115                           Monocytes        C4   1089  0.153547
# 151                   Transitioning MDM        C4   1322  0.134105
# 35                        Airway mucous        C4     91  0.120909
# 143  Pulmonary venous endothelial cells        C4    232  0.114925
# 163              Vascular smooth muscle        C4    297  0.110869
# 43                          Alveolar FB        C4    355  0.104465
# 79                      Dendritic cells        C4    213  0.093765
# 83                  ECM-high epithelial        C4    326  0.082006
# 15                       Adventitial FB        C4    788  0.081426
# 127                            Other FB        C4     78  0.080455
# 27                          Airway club        C4     96  0.077699
# 87          Endothelial cells (general)        C4    304  0.076649
# 135                           Pericytes        C4     21  0.048055
# 47                 Alveolar macrophages        C4  10873  0.043136
# 75                   Cycling epithelial        C4     71  0.040955
# 23                      Airway ciliated        C4    639  0.040548
# 91            Endothelial cells (other)        C4    150  0.039627
# 19                         Airway basal        C4     23  0.037043
# 39                 Airway smooth muscle        C4     26  0.029440
# 155                               Tregs        C4     22  0.023052
# 159                           Tuft-like        C4     39  0.020855
# 71                   Cycling NK/T cells        C4     65  0.013560
# 103                          Mast cells        C4     62  0.008595
# 11                    Activated B cells        C4     48  0.003149
# 63                         CD8+ T cells        C4     23  0.000300
# 55                              B cells        C4      9 -0.001247
# 59                         CD4+ T cells        C4    111 -0.003061
# 119                            NK cells        C4     50 -0.008377
# 139                        Plasma cells        C4    359 -0.011406
# 31                        Airway goblet        C4    218 -0.014146
# 147   Systemic venous endothelial cells        C4    223 -0.022605

# %%
df.cell_type_fine = pd.Categorical(df.cell_type_fine,categories=df[df.age_class.isin(['C4'])].sort_values(by='Fraction',ascending=False).cell_type_fine.to_list(),ordered=True)
df.head(10)
# Out:
#       cell_type_fine age_class  count  Fraction
# 0                AT1        C1    335 -0.019913
# 1                AT1        C2   3792 -0.219040
# 2                AT1        C3   3175  0.000463
# 3                AT1        C4   2306  0.238490
# 4                AT2        C1   1370 -0.104516
# 5                AT2        C2   6440 -0.203952
# 6                AT2        C3   2549  0.149030
# 7                AT2        C4    982  0.159438
# 8  Activated B cells        C1    148 -0.015481
# 9  Activated B cells        C2    848  0.011414

# %%
sns.set(rc={'figure.figsize':(14,5)},font_scale=1.5)
sns.set_style("white")
ax = sns.scatterplot(x='cell_type_fine',
                        y='Fraction',
                        hue = 'age_class',
                        size = 'count',
                        data=df,
                        sizes=(100, 400),
                        palette=['#577590','#43aa8b','#f3722c','#f94144'],
                        alpha=0.6)
### plot yline 
plt.axhline(y=0.15, color='#bfc0c0', linestyle='--')
plt.axhline(y=-0.15, color='#bfc0c0', linestyle='--')
### out legend
plt.legend(bbox_to_anchor=(1,0.5), loc='center left', ncol=1)
plt.xticks(rotation=90,ha='right')
plt.setp(ax.get_xticklabels()[0:10], color='#f94144')
plt.ylabel('Fraction_diff')
plt.savefig("/home/wangjing/wangj/codebase/HUSI/Figures/model/Covid_Fra.png",dpi = 400,bbox_inches = 'tight')
# Out:
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/wangjing/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
