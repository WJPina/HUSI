# %%
## env:base
import os
import pandas as pd
import scanpy as sc

import matplotlib.pyplot as plt  # For plotting
import seaborn as sns            # For plotting
sns.set_style("white")
import numpy as np
import anndata

from scipy.stats import mannwhitneyu
import statsmodels.stats.multitest as smm

## plot
import seaborn as sns
import matplotlib.pyplot as plt

os.chdir("/home/wangjing/wangj/codebase/HUSI/")

# %%
# data downloaded from https://pubmed.ncbi.nlm.nih.gov/38279009/

# data preprocessing
dd='ReplogleWeissman2022_rpe1'
adata=sc.read_h5ad(dd+".h5ad")
adata

# remove low quality cells
pt_gene=adata.obs.perturbation.unique()
pt_gene=[x for x in pt_gene if 'control' not in x]
pt_gene=set(pt_gene) & set(adata.var_names)
print(len(pt_gene))

non_targeted_mask=adata.obs['perturbation']=='control'
non_targeted_means = {}
for gene in pt_gene:
    non_targeted_means[gene] = np.mean(adata[non_targeted_mask, :].obs_vector(gene))

# non_targeted_means
filtered_indices = []
for gene in pt_gene:
    perturbed_mask = adata.obs['perturbation'] == f'{gene}'
    gene_expression = adata[perturbed_mask, :].obs_vector(gene)
    threshold = non_targeted_means[gene] / 4

    valid_indices = np.where(gene_expression <= threshold)[0]
    global_indices = np.where(perturbed_mask)[0][valid_indices]
    filtered_indices.extend(global_indices)

adata_filtered = adata[filtered_indices, :]
adata_filtered 

pt_gene=adata.obs.perturbation.unique()
# pt_gene=[x for x in pt_gene if 'control' not in x]
print(len(pt_gene))

vn=set(adata.var_names)
noExp=set(pt_gene) - vn
print(len(noExp))

adata_sub=adata[adata.obs['perturbation'].isin(noExp)]
len(adata_sub.obs.perturbation.unique())

adatafinal=anndata.concat([adata_filtered,adata_sub],axis=0)
adatafinal

len(adatafinal.obs.perturbation.unique())

sc.pp.filter_cells(adatafinal,min_genes=200)
sc.pp.filter_genes(adatafinal,min_cells=3)
adatafinal
# Out:
# 2106
# 2394
# 288
# AnnData object with n_obs × n_vars = 228790 × 8749
#     obs: 'batch', 'gene', 'gene_id', 'transcript', 'gene_transcript', 'guide_id', 'percent_mito', 'UMI_count', 'z_gemgroup_UMI', 'core_scale_factor', 'core_adjusted_UMI_count', 'disease', 'cancer', 'cell_line', 'sex', 'age', 'perturbation', 'organism', 'perturbation_type', 'tissue_type', 'ncounts', 'ngenes', 'nperts', 'percent_ribo', 'celltype', 'n_genes'
#     var: 'n_cells'

# %%
adata=adatafinal

pt_gene=adata.obs.perturbation.unique()
print(len(pt_gene))
pt_gene=[x for x in pt_gene if 'control' not in x]
print(len(pt_gene))
# Out:
# 2394
# 2393

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
sc.pp.log1p(adata)

# %%
def cal_hUSI(adata):
    mm_l2 = pd.read_csv('Data/SenOCLR_12_1_drop.csv',index_col=0)
    genes = set(mm_l2.index) & set(adata.var_names)
    try:
        exp = adata[:,list(genes)].X.todense()
    except:
        exp = adata[:,list(genes)].X
    exp = pd.DataFrame(exp,index=adata.obs_names,columns=list(genes))
    score = []
    for row in range(len(exp)):  
        score.append(mm_l2.w[list(genes)].corr(exp.iloc[row],method='spearman'))
    return score

# %%
hUSI = cal_hUSI(adata)
adata.obs['hUSI'] = hUSI
adata.obs
# Out:
#                      batch           gene          gene_id         transcript  \
# cell_barcode
# AAACCCATCCAACCGG-21     21         PPP2CB  ENSG00000104695               P1P2
# AAACGCTAGTGATAGT-49     49         PPP2CB  ENSG00000104695               P1P2
# AACGAAAAGTAAACGT-33     33         PPP2CB  ENSG00000104695               P1P2
# AAGACTCAGGCTCAAG-56     56         PPP2CB  ENSG00000104695               P1P2
# AAGTCGTAGTAAACGT-2       2         PPP2CB  ENSG00000104695               P1P2
# ...                    ...            ...              ...                ...
# TTTGTTGTCGAACACT-49     49         KCNA10  ENSG00000143105  ENST00000369771.2
# TTTGTTGTCGAGAGAC-31     31          OR4K1  ENSG00000155249  ENST00000285600.4
# TTTGTTGTCGGCTCTT-36     36  non-targeting    non-targeting      non-targeting
# TTTGTTGTCGTTATCT-37     37          CEP68  ENSG00000011523               P1P2
# TTTGTTGTCTTTCCGG-22     22  non-targeting    non-targeting      non-targeting
#
#                                                      gene_transcript  \
# cell_barcode
# AAACCCATCCAACCGG-21                 6679_PPP2CB_P1P2_ENSG00000104695
# AAACGCTAGTGATAGT-49                 6679_PPP2CB_P1P2_ENSG00000104695
# AACGAAAAGTAAACGT-33                 6679_PPP2CB_P1P2_ENSG00000104695
# AAGACTCAGGCTCAAG-56                 6679_PPP2CB_P1P2_ENSG00000104695
# AAGTCGTAGTAAACGT-2                  6679_PPP2CB_P1P2_ENSG00000104695
# ...                                                              ...
# TTTGTTGTCGAACACT-49    4292_KCNA10_ENST00000369771.2_ENSG00000143105
# TTTGTTGTCGAGAGAC-31     5955_OR4K1_ENST00000285600.4_ENSG00000155249
# TTTGTTGTCGGCTCTT-36  11208_non-targeting_non-targeting_non-targeting
# TTTGTTGTCGTTATCT-37                  1510_CEP68_P1P2_ENSG00000011523
# TTTGTTGTCTTTCCGG-22  11270_non-targeting_non-targeting_non-targeting
#
#                                                               guide_id  \
# cell_barcode
# AAACCCATCCAACCGG-21  PPP2CB_+_30670275.23-P1P2|PPP2CB_+_30670289.23...
# AAACGCTAGTGATAGT-49  PPP2CB_+_30670275.23-P1P2|PPP2CB_+_30670289.23...
# AACGAAAAGTAAACGT-33  PPP2CB_+_30670275.23-P1P2|PPP2CB_+_30670289.23...
# AAGACTCAGGCTCAAG-56  PPP2CB_+_30670275.23-P1P2|PPP2CB_+_30670289.23...
# AAGTCGTAGTAAACGT-2   PPP2CB_+_30670275.23-P1P2|PPP2CB_+_30670289.23...
# ...                                                                ...
# TTTGTTGTCGAACACT-49  KCNA10_-_111061735.23-ENST00000369771.2|KCNA10...
# TTTGTTGTCGAGAGAC-31  OR4K1_-_20403828.23-ENST00000285600.4|OR4K1_+_...
# TTTGTTGTCGGCTCTT-36            non-targeting_02977|non-targeting_01146
# TTTGTTGTCGTTATCT-37  CEP68_-_65283588.23-P1P2|CEP68_-_65283603.23-P1P2
# TTTGTTGTCTTTCCGG-22            non-targeting_03462|non-targeting_00434
#
#                      percent_mito  UMI_count  z_gemgroup_UMI  \
# cell_barcode
# AAACCCATCCAACCGG-21      0.058505     4991.0       -0.515229
# AAACGCTAGTGATAGT-49      0.068958    14545.0        0.698256
# AACGAAAAGTAAACGT-33      0.057443    11507.0       -0.630857
# AAGACTCAGGCTCAAG-56      0.051307    12123.0        0.027935
# AAGTCGTAGTAAACGT-2       0.060373     5847.0       -1.344563
# ...                           ...        ...             ...
# TTTGTTGTCGAACACT-49      0.071890    13618.0        0.515106
# TTTGTTGTCGAGAGAC-31      0.064337    11533.0        0.046112
# TTTGTTGTCGGCTCTT-36      0.061335    11853.0        1.030208
# TTTGTTGTCGTTATCT-37      0.066311     8988.0       -0.422864
# TTTGTTGTCTTTCCGG-22      0.048590    18296.0        1.378922
#
#                      core_scale_factor  ...  organism  perturbation_type  \
# cell_barcode                            ...
# AAACCCATCCAACCGG-21           0.493396  ...     human             CRISPR
# AAACGCTAGTGATAGT-49           0.876616  ...     human             CRISPR
# AACGAAAAGTAAACGT-33           1.141283  ...     human             CRISPR
# AAGACTCAGGCTCAAG-56           0.960976  ...     human             CRISPR
# AAGTCGTAGTAAACGT-2            0.936004  ...     human             CRISPR
# ...                                ...  ...       ...                ...
# TTTGTTGTCGAACACT-49           0.876616  ...     human             CRISPR
# TTTGTTGTCGAGAGAC-31           0.918100  ...     human             CRISPR
# TTTGTTGTCGGCTCTT-36           0.644705  ...     human             CRISPR
# TTTGTTGTCGTTATCT-37           0.908722  ...     human             CRISPR
# TTTGTTGTCTTTCCGG-22           1.007874  ...     human             CRISPR
#
#                      tissue_type  ncounts ngenes  nperts percent_ribo  \
# cell_barcode
# AAACCCATCCAACCGG-21    cell_line   4925.0   1997       1     0.229239
# AAACGCTAGTGATAGT-49    cell_line  14395.0   3277       1     0.263147
# AACGAAAAGTAAACGT-33    cell_line  11370.0   3169       1     0.256376
# AAGACTCAGGCTCAAG-56    cell_line  11982.0   3073       1     0.305959
# AAGTCGTAGTAAACGT-2     cell_line   5763.0   2016       1     0.289259
# ...                          ...      ...    ...     ...          ...
# TTTGTTGTCGAACACT-49    cell_line  13395.0   3594       1     0.195521
# TTTGTTGTCGAGAGAC-31    cell_line  11317.0   3562       1     0.190421
# TTTGTTGTCGGCTCTT-36    cell_line  11672.0   3613       0     0.197310
# TTTGTTGTCGTTATCT-37    cell_line   8857.0   3030       1     0.191713
# TTTGTTGTCTTTCCGG-22    cell_line  18012.0   4599       0     0.179158
#
#                                              celltype n_genes      hUSI
# cell_barcode
# AAACCCATCCAACCGG-21  retinal pigment epithelial cells    1997  0.019032
# AAACGCTAGTGATAGT-49  retinal pigment epithelial cells    3277  0.134005
# AACGAAAAGTAAACGT-33  retinal pigment epithelial cells    3169 -0.010921
# AAGACTCAGGCTCAAG-56  retinal pigment epithelial cells    3073  0.009359
# AAGTCGTAGTAAACGT-2   retinal pigment epithelial cells    2016  0.073845
# ...                                               ...     ...       ...
# TTTGTTGTCGAACACT-49  retinal pigment epithelial cells    3594  0.086938
# TTTGTTGTCGAGAGAC-31  retinal pigment epithelial cells    3562  0.073359
# TTTGTTGTCGGCTCTT-36  retinal pigment epithelial cells    3613 -0.008919
# TTTGTTGTCGTTATCT-37  retinal pigment epithelial cells    3030  0.028007
# TTTGTTGTCTTTCCGG-22  retinal pigment epithelial cells    4599 -0.018801
#
# [228790 rows x 27 columns]

# %%
adata.obs['hUSI_raw']=hUSI
adata.obs['hUSI']=(adata.obs['hUSI']-adata.obs['hUSI'].min())/(adata.obs['hUSI'].max()-adata.obs['hUSI'].min())
adata.obs['hUSI'].max()
# Out:
# np.float64(1.0)

# %%
meta=adata.obs

control_data=meta[meta['perturbation']=='control']['hUSI']
exp_groups=meta['perturbation'].unique()

results_hUSI=[]

for group in exp_groups:
    if group != 'control':
        exp_data=meta[meta['perturbation']==group]['hUSI']

        #fc
        fc=exp_data.mean()/control_data.mean()
        deltaMean=exp_data.mean()-control_data.mean()

        #wilcoxon test
        stat, p_values = mannwhitneyu(exp_data,control_data,alternative='two-sided')

        # make data
        results_hUSI.append({
            'group':group,
            'fc':fc,
            'deltaMean':deltaMean,
            'pvalue':p_values
        })

results_hUSI=pd.DataFrame(results_hUSI)

pv=results_hUSI['pvalue'].values
reject,padj, _, _=smm.multipletests(pv,alpha=0.05,method='fdr_bh')
results_hUSI['padj']=padj
results_hUSI
# Out:
#         group        fc  deltaMean        pvalue          padj
# 0      PPP2CB  1.254381   0.075099  7.368168e-08  1.632595e-07
# 1       USPL1  1.424136   0.125214  5.187201e-05  8.729236e-05
# 2        COPA  1.315289   0.093080  4.835780e-02  6.347791e-02
# 3       USP39  1.272551   0.080463  1.038491e-03  1.578850e-03
# 4       EIF3J  1.084295   0.024886  1.332752e-01  1.649056e-01
# ...       ...       ...        ...           ...           ...
# 2388  TNFSF10  1.442909   0.130757  2.856769e-02  3.849239e-02
# 2389    CPEB1  1.903927   0.266859  1.990563e-11  6.162248e-11
# 2390  DCLRE1B  1.980220   0.289383  9.198530e-08  2.021311e-07
# 2391    GINS3  1.988711   0.291890  7.649524e-12  2.468195e-11
# 2392    TAF1A  2.030303   0.304168  2.047515e-06  3.922900e-06
#
# [2393 rows x 5 columns]

# %%
results_hUSI.to_csv('Data/RPE1_hUSI_'+dd+'_fc_SenOCLR_l2_1_drop.csv',sep='\t')
meta.to_csv('Data/RPE1_hUSI_'+dd+'_meta_SenOCLR_l2_1_drop.csv',sep='\t')

# %%
print(results_hUSI.shape)
res_sig=results_hUSI[results_hUSI['padj'] < 0.05]

print(res_sig.shape)
res_sig=results_hUSI[(results_hUSI['padj'] < 0.05) & (results_hUSI['fc'] > 2)]
print(res_sig.shape)

res_sig=res_sig.sort_values(by='fc',ascending=False)
res_sig.reset_index(drop=True,inplace=True)
res_sig.index +=1

res_sig.head(20)
# Out:
# (2393, 5)
# (1808, 5)
# (264, 5)
#        group        fc  deltaMean        pvalue          padj
# 1       NACA  2.356832   0.400567  3.596164e-15  1.605526e-14
# 2       ECT2  2.347625   0.397849  7.635228e-13  2.735982e-12
# 3       PWP2  2.346738   0.397587  2.041249e-09  5.263696e-09
# 4      PRIM1  2.333028   0.393540  1.404089e-24  1.480169e-23
# 5      PSMA7  2.324195   0.390932  3.167716e-12  1.058707e-11
# 6     INCENP  2.319369   0.389507  2.406473e-05  4.160903e-05
# 7     PSMD13  2.313703   0.387835  8.439610e-16  4.039197e-15
# 8      PSMD2  2.304741   0.385189  9.738258e-13  3.467805e-12
# 9      DDX49  2.293894   0.381986  2.664407e-07  5.568494e-07
# 10    PDCD11  2.292617   0.381609  2.097677e-28  3.079596e-27
# 11     PSMB7  2.291012   0.381136  3.766971e-09  9.389960e-09
# 12    POLR1A  2.276929   0.376978  1.516806e-07  3.249523e-07
# 13  RPS19BP1  2.273319   0.375912  1.700025e-15  7.930136e-15
# 14      EMG1  2.269377   0.374749  3.460799e-08  7.887325e-08
# 15      NLE1  2.265290   0.373542  5.639982e-22  4.872374e-21
# 16     RIOK2  2.263315   0.372959  6.658835e-09  1.624321e-08
# 17     DDX21  2.257015   0.371099  1.893399e-16  9.619753e-16
# 18      WDR3  2.256324   0.370895  2.332365e-14  9.601650e-14
# 19   RSL24D1  2.255671   0.370702  9.701846e-08  2.120230e-07
# 20     PSMC6  2.253279   0.369996  7.297047e-10  1.984299e-09

# %%
sc.pp.highly_variable_genes(adata,n_top_genes=2000, inplace=True)
adata.raw=adata
adata=adata[:,adata.var.highly_variable]
sc.pp.scale(adata,max_value=10)

# %%
## PCA
sc.tl.pca(adata,svd_solver='arpack')
sc.pl.pca(adata,color='hUSI')
sc.pl.pca_variance_ratio(adata,log=True)

# %%
##umap
sc.pp.neighbors(adata,n_pcs=10)
sc.tl.umap(adata)
sc.pl.umap(adata,color=['hUSI'])

# %%
adata.obs['group']=adata.obs['perturbation'].apply(lambda x: 'control' if x=='control' else 'perturbations')
adata.obs['group'].value_counts()

# %%
sc.pp.neighbors(adata,n_pcs=10)
sc.tl.umap(adata)

### all cells
sns.set(rc={'figure.figsize':(25,20)},font_scale=1.5)
sc.set_figure_params(dpi_save=300)
sns.set_style("white")
sc.pl.umap(adata, color=['group'],s=5,palette=['#C75C64',"#CEDFEF"],save='Results/PerturbSeq/scPerturb_seq_RPE1_umap_perturbation.pdf',show = True,title='Conditions')
